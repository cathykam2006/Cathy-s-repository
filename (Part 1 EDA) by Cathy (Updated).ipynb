# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('COVID-19_Vaccination_Age_and_Sex_Trends_in_the_United_States__National_and_Jurisdictional.csv')

# %%
df.describe()
# Out:
#              census  Administered_Dose1  Series_Complete_Yes  Booster_Doses  \
# count  1.783500e+06        1.528941e+06         1.460020e+06   8.674850e+05
# mean   1.108500e+06        7.959796e+05         7.065700e+05   3.862255e+05
# std    6.418177e+06        4.744900e+06         4.176821e+06   2.225752e+06
# min    1.800000e+02        1.100000e+01         1.100000e+01   1.100000e+01
# 25%    6.083650e+04        1.483400e+04         1.303200e+04   8.201000e+03
# 50%    2.135670e+05        1.213790e+05         1.095525e+05   5.796000e+04
# 75%    5.827572e+05        4.211090e+05         3.780380e+05   2.129580e+05
# max    1.685463e+08        1.383906e+08         1.189151e+08   6.266048e+07
#
#        Second_Booster  Administered_Dose1_pct_agegroup  \
# count    3.780100e+05                     1.460358e+06
# mean     1.180257e+05                     6.027572e+01
# std      7.308689e+05                     3.304679e+01
# min      1.100000e+01                     0.000000e+00
# ...

# %%
df.head(20)

# %%
df.shape
# Out:
# (1870500, 12)

# %%
df['Date'].head()
# Out:
# 0    12/07/2022 12:00:00 AM
# 1    12/07/2022 12:00:00 AM
# 2    12/07/2022 12:00:00 AM
# 3    12/07/2022 12:00:00 AM
# 4    12/07/2022 12:00:00 AM
# Name: Date, dtype: object

# %%
df['Date'].tail()
# Out:
# 1870495    12/13/2020 12:00:00 AM
# 1870496    12/13/2020 12:00:00 AM
# 1870497    12/13/2020 12:00:00 AM
# 1870498    12/13/2020 12:00:00 AM
# 1870499    12/13/2020 12:00:00 AM
# Name: Date, dtype: object

# %% [markdown]
# # The overall distribution of population of completing entire vaccination series

# %%
df.drop(df[df.Location == 'US'].index, inplace=True)

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(data = df.sort_values(['Series_Complete_Yes'], ascending = False), y = 'Series_Complete_Yes', 
            x = 'Location');
plt.ylabel('Population Per 10 million')
plt.xlabel('Locations')
plt.title('The Overall Distribution of Entire Vaccination Series completed');

# %% [markdown]
# # The overall distribution of Completing Adminstered Dose 1

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(data = df.sort_values(['Administered_Dose1'], ascending = False), y = 'Administered_Dose1', 
            x = 'Location');
plt.ylabel('Population Per Million')
plt.xlabel('Locations')
plt.title('The Overall Distribution of Completing Adminstered Dose 1');

# %% [markdown]
# # The overall distribution of Booster Doses across different locations

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(data = df.sort_values(['Booster_Doses'], ascending = False), y = 'Booster_Doses', 
            x = 'Location')
plt.ylabel('Population Per Million')
plt.xlabel('Locations')
plt.title('The Overall Distribution of Completing 1st Booster Doses');

# %%
fig, ax = plt.subplots(figsize=(20,10))
sns.barplot(data = df.sort_values(['Second_Booster'], ascending = False), y = 'Second_Booster', 
            x = 'Location')
plt.ylabel('Population Per Million')
plt.xlabel('Locations')
plt.title('The Overall Distribution of Completing 2nd Booster Doses');

# %%
#In case Locations don't pop up
#df.set_index('Location', inplace = True)

# %%
fig, ax = plt.subplots(figsize=(40,30))
sns.barplot(data = df.sort_values(['Demographic_Category'], ascending = True), x = 'Series_Complete_Yes', 
            y = 'Demographic_Category')
plt.ylabel('Age Demographic')
plt.xlabel('Population per million')
plt.xticks(fontsize = 20)
plt.title('The Overall Demographic of Completing the Entire Vaccination Series');

# %%
sns.barplot(x= df.Demographic_Category.str.contains('Female'), y= df.Series_Complete_Yes, ax=ax, label="Entire Vaccination series completed")
# Out:
# <AxesSubplot:title={'center':'The Overall Demographic of Completing Entire Vaccination Series'}, xlabel='Demographic_Category', ylabel='Series_Complete_Yes'>

# %%
df.Demographic_Category.unique()
# Out:
# array(['Female_Ages_25-39_yrs', 'Sex_Female', 'Female_Ages_65+_yrs',
#        'Male_Ages_2-4_yrs', 'Ages_25-49_yrs', 'Ages_65+_yrs',
#        'Female_Ages_40-49_yrs', 'Age_Unknown', 'Ages_12-17_yrs',
#        'Female_Ages_<5yrs', 'Male_Ages_50-64_yrs', 'Male_Ages_5-11_yrs',
#        'Ages_75+_yrs', 'Male_Ages_12-17_yrs', 'Ages_40-49_yrs',
#        'Male_Ages_75+_yrs', 'Female_Ages_18-24_yrs',
#        'Female_Ages_75+_yrs', 'Ages_2-4_yrs', 'Male_Ages_65-74_yrs',
#        'Female_Ages_50-64_yrs', 'Ages_<5yrs', 'Male_Ages_25-39_yrs',
#        'Male_Ages_<2yrs', 'Female_Ages_65-74_yrs', 'Sex_Male',
#        'Ages_65-74_yrs', 'Male_Ages_25-49_yrs', 'Female_Ages_<2yrs',
#        'Female_Ages_12-17_yrs', 'Female_Ages_25-49_yrs', 'Ages_<2yrs',
#        'Ages_18-24_yrs', 'Female_Ages_2-4_yrs', 'Female_Ages_5-11_yrs',
#        'Male_Ages_40-49_yrs', 'Male_Ages_<5yrs', 'Ages_25-39_yrs',
#        'Male_Ages_18-24_yrs', 'Male_Ages_65+_yrs', 'Ages_50-64_yrs',
# ...

# %%
sns.set(style="whitegrid")
  
ax = sns.scatterplot(x='Series_Complete_Yes', y='census', data=df)

ax.set(xlabel ='Population Completed Entire Vaccination (per 10 million)', ylabel ='Census Population (per 10 million)')

plt.title('The Relationship between Completion of Entire Vaccination and the Census', fontsize=15)

plt.show()

# %%
sns.set(style="whitegrid")
  
ax = sns.scatterplot(x='Administered_Dose1', y='Booster_Doses', data=df)

ax.set(xlabel ='Population Completed Dose 1 per 10 million', ylabel ='Population received Booster Doses per 10 million')

plt.title('The Relationship between Completion of Dose 1 and Booster Doses', fontsize=15)

plt.show()

# %%
df['Date'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
df.dtypes
# Out:
# Date                                datetime64[ns]
# Location                                    object
# Demographic_Category                        object
# census                                     float64
# Administered_Dose1                         float64
# Series_Complete_Yes                        float64
# Booster_Doses                              float64
# Second_Booster                             float64
# Administered_Dose1_pct_agegroup            float64
# Series_Complete_Pop_pct_agegroup           float64
# Booster_Doses_Vax_pct_agegroup             float64
# Second_Booster_Vax_pct_agegroup            float64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df.Date)
df['Date']
# Out:
# 0         2022-12-07
# 1         2022-12-07
# 2         2022-12-07
# 3         2022-12-07
# 4         2022-12-07
#              ...
# 1870495   2020-12-13
# 1870496   2020-12-13
# 1870497   2020-12-13
# 1870498   2020-12-13
# 1870499   2020-12-13
# Name: Date, Length: 1870500, dtype: datetime64[ns]

# %%
df_date = df.groupby('Date', as_index = False).sum().sort_values(by = 'Date')
df_date
# Out:
#           Date        census  Administered_Dose1  Series_Complete_Yes  \
# 0   2020-12-13  2.726910e+09        2.836850e+05         7.107500e+04
# 1   2020-12-14  2.726910e+09        3.231670e+05         7.229600e+04
# 2   2020-12-15  2.726910e+09        7.237170e+05         7.478600e+04
# 3   2020-12-16  2.726910e+09        2.056563e+06         7.910900e+04
# 4   2020-12-17  2.726910e+09        4.346173e+06         8.603800e+04
# ..         ...           ...                 ...                  ...
# 720 2022-12-03  2.726910e+09        2.202875e+09         1.883996e+09
# 721 2022-12-04  2.726910e+09        2.202974e+09         1.884061e+09
# 722 2022-12-05  2.726910e+09        2.203149e+09         1.884190e+09
# 723 2022-12-06  2.726910e+09        2.203184e+09         1.884219e+09
# 724 2022-12-07  2.726910e+09        2.203184e+09         1.884219e+09
#
#      Booster_Doses  Second_Booster  Administered_Dose1_pct_agegroup  \
# ...

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.set(style="whitegrid")
  
ax = sns.lineplot(x= df_date['Date'], y=df_date['Second_Booster'], data=df_date)

ax.set(xlabel ='Date', ylabel ='Completion of Second Booster (per 100,000,000)')

plt.title('The Completion of Second Booster From 12/13/2020 to now', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.set(style="whitegrid")
  
ax = sns.lineplot(x= df_date['Date'], y=df['Second_Booster'], data=df)

ax.set(xlabel ='Date', ylabel ='New Receival of Second Booster (per 10 million)')

plt.title('New Receival of Second Booster From 12/13/2020 to now', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.set(style="whitegrid")
  
ax = sns.lineplot(x= df_date['Date'], y=df['Administered_Dose1'], data=df)

ax.set(xlabel ='Date', ylabel ='New Receival of Administered Dose 1 (per 10 million)')

plt.title('New Receival of Administered Dose 1 From 12/13/2020 to now', fontsize=15)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.set(style="whitegrid")
  
ax = sns.lineplot(x= df_date['Date'], y=df['Booster_Doses'], data=df_date)

ax.set(xlabel ='Date', ylabel ='New Receival of Booster Doses (per 10 million)')

plt.title('New Receival of Booster Doses From 12/13/2020 to now', fontsize=15)

plt.show()
